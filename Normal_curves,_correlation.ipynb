# %%
#Import libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics as st
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr

#Normal curves
x = np.arange(-3, 3, 0.001)
mean=st.mean(x)
std=st.stdev(x)
plt.plot(x, norm.pdf(x,mean,std), color='red', linewidth=3)

# %%
#Correlation
con = pd.read_csv('/content/concrete_data.csv')

con.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
con.corr()
# Out:
#                                  cement  blast_furnace_slag   fly_ash  \
# cement                         1.000000           -0.275216 -0.397467
# blast_furnace_slag            -0.275216            1.000000 -0.323580
# fly_ash                       -0.397467           -0.323580  1.000000
# water                         -0.081587            0.107252 -0.256984
# superplasticizer               0.092386            0.043270  0.377503
# coarse_aggregate              -0.109349           -0.283999 -0.009961
# fine_aggregate                -0.222718           -0.281603  0.079108
# age                            0.081946           -0.044246 -0.154371
# concrete_compressive_strength  0.497832            0.134829 -0.105755
#
#                                   water  superplasticizer  coarse_aggregate  \
# cement                        -0.081587          0.092386         -0.109349
# blast_furnace_slag             0.107252          0.043270         -0.283999
# ...

# %%
#Scatter plot
df2=pd.read_csv('/content/heart.csv')
df2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
sns.scatterplot(x="trestbps", y="thalach", data=df2);

# %%
#Correlation coefficient
list1 = con['concrete_compressive_strength']
list2 = con['fly_ash']
corr, _ = pearsonr(list1, list2)

print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.106

# %%
list3=df2['trestbps']
list4=df2['thalach']
corr, _ = pearsonr(list3, list4)

print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.039
