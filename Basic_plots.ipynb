# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Iris.csv')
df1=df.head(20)

# %%
plt.scatter(df['Species'],df['SepalLengthCm'])

# %%
plt.hist(df['SepalLengthCm'],edgecolor='Black')
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(df1['SepalWidthCm'],labels=df1['Species'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6f30f08460>,
# ...
#  [Text(1.0863013903930647, 0.17305862945861594, 'Iris-setosa'),
#   Text(0.9898314498146161, 0.47982674056152314, 'Iris-setosa'),
#   Text(0.8187869584531428, 0.7345664821287803, 'Iris-setosa'),
#   Text(0.579820241237199, 0.9347772396949107, 'Iris-setosa'),
#   Text(0.2750976483901837, 1.0650452027262463, 'Iris-setosa'),
#   Text(-0.09422229442879204, 1.09595718859478, 'Iris-setosa'),
#   Text(-0.4437785176081681, 1.0065091292728034, 'Iris-setosa'),
#   Text(-0.7271449132111957, 0.8253849254687676, 'Iris-setosa'),
#   Text(-0.9295048020066368, 0.5882353466484341, 'Iris-setosa'),
#   Text(-1.052993964067438, 0.31812530807457545, 'Iris-setosa'),
#   Text(-1.09989915229215, -0.014894790599743203, 'Iris-setosa'),
#   Text(-1.0392053695139603, -0.36062750861984116, 'Iris-setosa'),
#   Text(-0.8934079136336454, -0.6417338232139373, 'Iris-setosa'),
#   Text(-0.6891612209117508, -0.8573545425268506, 'Iris-setosa'),
# ...

# %%
plt.bar(df['Species'],df['SepalLengthCm'])
# Out:
# <BarContainer object of 150 artists>

# %%
plt.plot(df['Species'],df['SepalLengthCm'])

# %%
plt.stem(df['SepalWidthCm'],df['SepalLengthCm'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.(df['SepalLengthCm']
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6f30a88fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6f30a99580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6f30a88cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6f30a99b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6f30a99df0>],
#  'means': []}

# %%
df.plot.area()
# Out:
# <AxesSubplot:>
